# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pickle

# %%
data=pd.read_csv("aug_train.csv", header=0)

# %%
data
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.isnull().sum()*100/len(data)
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     0.000000
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# last_new_job               2.207955
# training_hours             0.000000
# target                     0.000000
# dtype: float64

# %%
features=[]
for i in data.columns:
    null_values= data[i].isnull().sum()/data.shape[0]
    if null_values<0.3:
        features.append(i)

# %%
for i in data.columns:
    print(data[i].isnull().sum()/data.shape[0])
# Out:
# 0.0
# 0.0
# 0.0
# 0.23530639941538783
# 0.0
# 0.020148240943731077
# 0.02401085708320284
# 0.1468316108153252
# 0.0033928385008873576
# 0.3099488464349097
# 0.32049274454535964
# 0.02207954901346696
# 0.0
# 0.0

# %%
features
# Out:
# ['enrollee_id',
#  'city',
#  'city_development_index',
#  'gender',
#  'relevent_experience',
#  'enrolled_university',
#  'education_level',
#  'major_discipline',
#  'experience',
#  'last_new_job',
#  'training_hours',
#  'target']

# %%
data.select_dtypes(include='object').columns
# Out:
# Index(['city', 'gender', 'relevent_experience', 'enrolled_university',
#        'education_level', 'major_discipline', 'experience', 'company_size',
#        'company_type', 'last_new_job'],
#       dtype='object')

# %%
for i in data.select_dtypes(include='object').columns:
    plt.figure(figsize=(10, 20))
    sns.countplot(data= data, x=i)

# %%
from sklearn.impute import SimpleImputer

si= SimpleImputer(strategy='most_frequent')
si_object= pd.DataFrame(si.fit_transform(data.select_dtypes(include='object')), columns=data.select_dtypes(include='object').columns)


for  i in si_object.columns:
    data[i]= si_object[i]

# %%
from sklearn import preprocessing

le= LabelEncoder()

# %%
target= data['target']

# %%
final=data.drop('target', axis=1)
final
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624   Male
# 3            33241  city_115                   0.789   Male
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855   Male
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
target=target.astype('int64')
target
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 19153    1
# 19154    1
# 19155    0
# 19156    0
# 19157    0
# Name: target, Length: 19158, dtype: int64

# %%
finals= final.apply(LabelEncoder().fit_transform)
finals
# Out:
#        enrollee_id  city  city_development_index  gender  relevent_experience  \
# 0             5018     5                      85       1                    0
# 1            16986    77                      48       1                    1
# 2             6499    64                      14       1                    1
# 3            19067    14                      52       1                    1
# 4              358    50                      45       1                    0
# ...            ...   ...                     ...     ...                  ...
# 19153         4117    55                      71       1                    1
# 19154        17981     5                      85       1                    0
# 19155        14021     5                      85       1                    0
# 19156         3185    94                      56       1                    0
# 19157        13567    95                      67       1                    1
#
# ...

# %%
Finals=finals.drop(['enrollee_id','city_development_index','enrolled_university','major_discipline','company_size','company_type','last_new_job','training_hours','city'], axis=1)

# %%
Finals
# Out:
#        gender  relevent_experience  education_level  experience
# 0           1                    0                0          21
# 1           1                    1                0           6
# 2           1                    1                0          15
# 3           1                    1                0          20
# 4           1                    0                2          21
# ...       ...                  ...              ...         ...
# 19153       1                    1                0           5
# 19154       1                    0                0           5
# 19155       1                    0                0          21
# 19156       1                    0                1          20
# 19157       1                    1                4          11
#
# [19158 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test= train_test_split(Finals, target, test_size=0.3, random_state=987)

# %%
from sklearn import svm
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
X_train
# Out:
#        gender  relevent_experience  education_level  experience
# 4322        1                    0                0          15
# 10954       1                    1                0          11
# 17168       1                    0                2          19
# 17254       1                    0                0          12
# 4883        1                    1                0          14
# ...       ...                  ...              ...         ...
# 13955       1                    1                4           0
# 3226        1                    0                0          16
# 18473       1                    0                1          11
# 5607        1                    0                3          14
# 6067        1                    1                0          20
#
# [13410 rows x 4 columns]

# %%
cl= svm.SVC(max_iter=2)

# %%
cl.fit(X_train, y_train)
# Out:
# C:\Users\AnirudhMadhusudan\anaconda3\lib\site-packages\sklearn\svm\_base.py:246: ConvergenceWarning: Solver terminated early (max_iter=2).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn('Solver terminated early (max_iter=%i).'
# SVC(max_iter=2)

# %%
pred= cl.predict(X_test)

# %%
accuracy_score(y_test, pred)
# Out:
# 0.47390396659707723

# %%
f= open('hr_analytics.pkl', 'wb')

pickle.dump(cl, f)

# %%
y_train
# Out:
# 4322     1.0
# 10954    1.0
# 17168    0.0
# 17254    0.0
# 4883     0.0
#         ...
# 13955    0.0
# 3226     0.0
# 18473    1.0
# 5607     0.0
# 6067     0.0
# Name: target, Length: 13410, dtype: float64
